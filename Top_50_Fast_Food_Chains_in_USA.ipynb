# %% [markdown]
# <a href="https://colab.research.google.com/github/AjanakuBen/Data-Wrangling-and-Cleaning-in-Python/blob/main/Top_50_Fast_Food_Chains_in_USA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import necessary libraries
import numpy as np
import pandas as pd

# %% [markdown]
# **DATA CLEANING WITH TOP 50 FAST FOOD CHAINS IN USA**

# %%
data = pd.read_csv("Top 50 Fast-Food Chains in USA.csv", encoding = "latin") #import the csv file
data.head()
# Out:
#   Fast-Food Chains   U.S._Systemwide_Sales  Average_Sales_per_Unit    \
# 0           Arbyâs                    4462                      1309
# 1   Baskin-Robbins                     686                       296
# 2       Bo jangles                    1485                      1924
# 3      Burger King                   10033                      1470
# 4       Carlas Jr.                    1560                      1400
#
#    Franchised_Stores  Company_Stores  2021_Total_Units  \
# 0               2293            1116              3409
# 1               2317               0              2317
# 2                496             277               773
# 3               7054              51              7105
# 4               1011              47              1058
#
#    Total_Change_in_Units_from_2020
# 0                               40
# 1                              102
# 2                               15
# 3                               24
# 4                              -21

# %%
data.shape #the dataset has 50 rows and 7 columns
# Out:
# (50, 7)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Fast-Food Chains                 50 non-null     object
#  1    U.S._Systemwide_Sales           50 non-null     int64
#  2   Average_Sales_per_Unit           50 non-null     int64
#  3   Franchised_Stores                50 non-null     int64
#  4   Company_Stores                   50 non-null     int64
#  5   2021_Total_Units                 50 non-null     int64
#  6   Total_Change_in_Units_from_2020  50 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 2.9+ KB

# %%
data.columns
# Out:
# Index(['Fast-Food Chains', ' U.S._Systemwide_Sales',
#        'Average_Sales_per_Unit  ', 'Franchised_Stores', 'Company_Stores',
#        '2021_Total_Units', 'Total_Change_in_Units_from_2020'],
#       dtype='object')

# %%
data.dtypes #check inconsistent data types
# Out:
# Fast-Food Chains                   object
#  U.S._Systemwide_Sales              int64
# Average_Sales_per_Unit              int64
# Franchised_Stores                   int64
# Company_Stores                      int64
# 2021_Total_Units                    int64
# Total_Change_in_Units_from_2020     int64
# dtype: object

# %%
print(data[" U.S._Systemwide_Sales"].astype(float)) #convert the column "U.S._Systemwide_Sales" int datatype to float
# Out:
# 0      4462.0
# 1       686.0
# 2      1485.0
# 3     10033.0
# 4      1560.0
# 5       931.0
# 6     16700.0
# 7      7547.0
# 8       776.0
# 9      2489.0
# 10     4494.0
# 11      931.0
# 12     8641.0
# 13    10416.0
# 14      973.0
# 15     1044.0
# 16     2093.0
# 17      759.0
# 18     2100.0
# 19     1175.0
# 20     4077.0
# 21     2203.0
# 22     2301.0
# 23     5100.0
# 24      996.0
# 25     4185.0
# 26      899.0
# 27      869.0
# 28    45960.0
# 29      661.0
# 30     4452.0
# 31     5650.0
# 32     3486.0
# 33      809.0
# 34     5500.0
# 35     4775.0
# 36      835.0
# 37     2377.0
# 38      777.0
# 39     5835.0
# 40    24300.0
# 41     9350.0
# 42    12600.0
# 43      687.0
# 44      948.0
# 45    11111.0
# 46     3089.0
# 47      615.0
# 48     2278.0
# 49     2233.0
# Name:  U.S._Systemwide_Sales, dtype: float64

# %%
print(data["Average_Sales_per_Unit  "].astype(float)) #convert the column "Average_Sales_per_Unit" int datatype to float
# Out:
# 0     1309.0
# 1      296.0
# 2     1924.0
# 3     1470.0
# 4     1400.0
# 5     1145.0
# 6     6100.0
# 7     2641.0
# 8      870.0
# 9     3099.0
# 10    1036.0
# 11    1551.0
# 12    1317.0
# 13    1127.0
# 14    2000.0
# 15     909.0
# 16    3172.0
# 17    1842.0
# 18    1117.0
# 19    3200.0
# 20    1843.0
# 21    1145.0
# 22     866.0
# 23    1408.0
# 24    4000.0
# 25    1000.0
# 26     934.0
# 27    1866.0
# 28    3420.0
# 29    1073.0
# 30    2173.0
# 31    2700.0
# 32    1147.0
# 33     643.0
# 34    1022.0
# 35    1867.0
# 36    1006.0
# 37    4893.0
# 38    3679.0
# 39    1643.0
# 40    1200.0
# 41     438.0
# 42    1823.0
# 43    1200.0
# 44    1009.0
# 45    1895.0
# 46    3640.0
# 47    1749.0
# 48    1592.0
# 49    2484.0
# Name: Average_Sales_per_Unit  , dtype: float64

# %%
data.dtypes
# Out:
# Fast-Food Chains                   object
#  U.S._Systemwide_Sales              int64
# Average_Sales_per_Unit              int64
# Franchised_Stores                   int64
# Company_Stores                      int64
# 2021_Total_Units                    int64
# Total_Change_in_Units_from_2020     int64
# dtype: object

# %%
data
# Out:
#                            Fast-Food Chains   U.S._Systemwide_Sales  \
# 0                                    Arbyâs                    4462
# 1                            Baskin-Robbins                     686
# 2                                Bo jangles                    1485
# 3                               Burger King                   10033
# 4                                Carlas Jr.                    1560
# 5                          Checkers/Rally's                     931
# 6                               Chick-fil-A                   16700
# 7                                  Chipotle                    7547
# 8                          Church's Chicken                     776
# 9                                  Culverâs                    2489
# 10                              Dairy Queen                    4494
# 11                                 Del Taco                     931
# 12                                 Domino's                    8641
# ...

# %%
data.isnull().any() #check for missing values
# Out:
# Fast-Food Chains                   False
#  U.S._Systemwide_Sales             False
# Average_Sales_per_Unit             False
# Franchised_Stores                  False
# Company_Stores                     False
# 2021_Total_Units                   False
# Total_Change_in_Units_from_2020    False
# dtype: bool

# %%
data.isnull().sum().sum() #the total number of missing values
# Out:
# 0

# %%
data.duplicated().any() #check if there is duplicated values
# Out:
# False

# %%
data["Fast-Food Chains"] = data["Fast-Food Chains"].str.replace("â","'") #In the "Fast-Food Chains" column, the character â was replaced with " ' "

# %%
data
# Out:
#                            Fast-Food Chains   U.S._Systemwide_Sales  \
# 0                                  Arby ' s                    4462
# 1                            Baskin-Robbins                     686
# 2                                Bo jangles                    1485
# 3                               Burger King                   10033
# 4                                Carlas Jr.                    1560
# 5                          Checkers/Rally's                     931
# 6                               Chick-fil-A                   16700
# 7                                  Chipotle                    7547
# 8                          Church's Chicken                     776
# 9                                Culver ' s                    2489
# 10                              Dairy Queen                    4494
# 11                                 Del Taco                     931
# 12                                 Domino's                    8641
# ...

# %% [markdown]
# DATA CLEANING DONE!
