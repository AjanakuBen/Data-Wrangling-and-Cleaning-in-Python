# %% [markdown]
# <a href="https://colab.research.google.com/github/AjanakuBen/Data-Wrangling-and-Cleaning-in-Python/blob/main/Food_Balance_Sheets_E_Africa_NOFLAG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import necessary python libraries
import numpy as np
import pandas as pd

# %% [markdown]
# **DATA CLEANING WITH FOOD BALANCE SHEETS_E_AFRICA_NOFLAG**

# %%
df = pd.read_csv("FoodBalanceSheets_E_Africa_NOFLAG.csv", encoding = "latin") #import the csv file (food balance sheet)
df
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
df.shape
# Out:
# (60943, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60943 entries, 0 to 60942
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area Code     60943 non-null  int64
#  1   Area          60943 non-null  object
#  2   Item Code     60943 non-null  int64
#  3   Item          60943 non-null  object
#  4   Element Code  60943 non-null  int64
#  5   Element       60943 non-null  object
#  6   Unit          60943 non-null  object
#  7   Y2014         59354 non-null  float64
#  8   Y2015         59395 non-null  float64
#  9   Y2016         59408 non-null  float64
#  10  Y2017         59437 non-null  float64
#  11  Y2018         59507 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 5.6+ MB

# %%
df.describe(include = "all")
# Out:
#            Area Code   Area     Item Code                     Item  \
# count   60943.000000  60943  60943.000000                    60943
# unique           NaN     49           NaN                      119
# top              NaN  Kenya           NaN  Milk - Excluding Butter
# freq             NaN   1560           NaN                     1262
# mean      134.265576    NaN   2687.176706                      NaN
# std        72.605709    NaN    146.055739                      NaN
# min         4.000000    NaN   2501.000000                      NaN
# 25%        74.000000    NaN   2562.000000                      NaN
# 50%       136.000000    NaN   2630.000000                      NaN
# 75%       195.000000    NaN   2775.000000                      NaN
# max       276.000000    NaN   2961.000000                      NaN
#
#         Element Code                   Element         Unit          Y2014  \
# count   60943.000000                     60943        60943   59354.000000
# ...

# %%
df.isnull().any() #check if there are missing values
# Out:
# Area Code       False
# Area            False
# Item Code       False
# Item            False
# Element Code    False
# Element         False
# Unit            False
# Y2014            True
# Y2015            True
# Y2016            True
# Y2017            True
# Y2018            True
# dtype: bool

# %%
df.isnull().sum() #number of missing values in each columns
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
df.isnull().sum().sum() #total number of missing values in the dataset
# Out:
# 7614

# %%
df.columns
# Out:
# Index(['Area Code', 'Area', 'Item Code', 'Item', 'Element Code', 'Element',
#        'Unit', 'Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018'],
#       dtype='object')

# %%
df_columns = df.columns.str.upper()
df_columns
# Out:
# Index(['AREA CODE', 'AREA', 'ITEM CODE', 'ITEM', 'ELEMENT CODE', 'ELEMENT',
#        'UNIT', 'Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018'],
#       dtype='object')

# %%
df1 = df.rename(columns = {"Area":"Country"}) #rename the column "Area" with "Country"
df1.head()
# Out:
#    Area Code  Country  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
df1.isnull().sum()
# Out:
# Area Code          0
# Country            0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
df1["Y2014"].mean() #fill the missing values with the mean of column "Y2014"
# Out:
# 134.1962821376824

# %%
df1["Y2014"].fillna(df1["Y2014"].mean())
# Out:
# 0        38924.00
# 1            0.00
# 2         3377.00
# 3           94.90
# 4           80.06
#            ...
# 60938       42.00
# 60939        3.06
# 60940        3.00
# 60941        0.10
# 60942        0.04
# Name: Y2014, Length: 60943, dtype: float64

# %%
df1["Y2015"].fillna(df1["Y2015"].mean()) #fill the missing values with the mean of column "Y2015"
# Out:
# 0        39728.00
# 1            0.00
# 2         3379.00
# 3           94.35
# 4           79.36
#            ...
# 60938       46.00
# 60939        3.33
# 60940        4.00
# 60941        0.11
# 60942        0.05
# Name: Y2015, Length: 60943, dtype: float64

# %%
df1["Y2016"].fillna(df1["Y2016"].mean()) #fill the missing values with the mean of column "Y2016"
# Out:
# 0        40551.00
# 1            0.00
# 2         3372.00
# 3           94.72
# 4           77.40
#            ...
# 60938       33.00
# 60939        2.35
# 60940        3.00
# 60941        0.08
# 60942        0.03
# Name: Y2016, Length: 60943, dtype: float64

# %%
df1["Y2017"].fillna(df1["Y2017"].mean()) #fill the missing values with the mean of column "Y2017"
# Out:
# 0        41389.00
# 1            0.00
# 2         3341.00
# 3           92.82
# 4           80.19
#            ...
# 60938       19.00
# 60939        1.33
# 60940        1.00
# 60941        0.04
# 60942        0.02
# Name: Y2017, Length: 60943, dtype: float64

# %%
df1["Y2018"].fillna(df1["Y2018"].mean()) #fill the missing values with the mean of column "Y2018"
# Out:
# 0        42228.00
# 1            0.00
# 2         3322.00
# 3           91.83
# 4           77.28
#            ...
# 60938       16.00
# 60939        1.08
# 60940        1.00
# 60941        0.04
# 60942        0.01
# Name: Y2018, Length: 60943, dtype: float64

# %%
df_fill = df1.fillna(df1.mean())
df_fill.head()
# Out:
# <ipython-input-59-59bc2fd0f6d4>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_fill = df1.fillna(df1.mean())
#    Area Code  Country  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# ...

# %%
df_fill.isnull().any()
# Out:
# Area Code       False
# Country         False
# Item Code       False
# Item            False
# Element Code    False
# Element         False
# Unit            False
# Y2014           False
# Y2015           False
# Y2016           False
# Y2017           False
# Y2018           False
# dtype: bool

# %%
df_fill.isnull().sum()
# Out:
# Area Code       0
# Country         0
# Item Code       0
# Item            0
# Element Code    0
# Element         0
# Unit            0
# Y2014           0
# Y2015           0
# Y2016           0
# Y2017           0
# Y2018           0
# dtype: int64

# %%
df_fill.duplicated().any() #check for duplicate values
# Out:
# False

# %%
df_fill.dtypes #check inconsistent data types
# Out:
# Area Code         int64
# Country          object
# Item Code         int64
# Item             object
# Element Code      int64
# Element          object
# Unit             object
# Y2014           float64
# Y2015           float64
# Y2016           float64
# Y2017           float64
# Y2018           float64
# dtype: object

# %%
df_fill
# Out:
#        Area Code   Country  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %% [markdown]
# **DATA CLEANING DONE!**
